# %%
from __future__ import print_function

import os
from skimage.transform import resize
from skimage.io import imsave
import numpy as np
from keras.models import Model
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Conv2DTranspose
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from keras import backend as K

from data import load_train_data, load_test_data, load_test_data_all, load_test_data_all_tv
from data import load_train_data_312, load_test_data_312
from utils import crop_resize, de_crop_resize, save_mean_std, load_mean_std, shift_augmentation
# Out:
# Using TensorFlow backend.

# %%
K.set_image_data_format('channels_last')  # TF dimension ordering in this code

img_rows_orig = 600
img_cols_orig = 800
img_rows = 400
img_cols = 400
img_ds_rows = 192 # change this to adjust downsampling rate
img_ds_cols = 192 # and this

pred_dir = 'preds_d2' # where the prediction is saved

smooth = 1.

def load_test_data():
    imgs_test = np.load('imgs_test.npy')
    imgs_id = np.load('imgs_test_id.npy')
    return imgs_test, imgs_id

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)


def get_unet():
    inputs = Input((img_ds_rows, img_ds_cols, 3))
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_uniform')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid', kernel_initializer='glorot_uniform')(conv9)

    model = Model(inputs=[inputs], outputs=[conv10])

    model.compile(optimizer=Adam(lr=1e-4), loss=dice_coef_loss, metrics=[dice_coef])

    return model

def preprocess(imgs):
    if len(imgs.shape) == 3:
        imgs = imgs.reshape(imgs.shape[0], imgs.shape[1], imgs.shape[2], 1)

    imgs_p = np.ndarray((imgs.shape[0], img_ds_rows, img_ds_cols, imgs.shape[3]), dtype=np.float32)
    for i in range(imgs.shape[0]):
        imgs_p[i] = crop_resize(imgs[i,:,:,:], img_ds_cols, img_ds_rows, Resize = True)
        #imgs_p[i] = resize(imgs[i], (img_cols, img_rows), preserve_range=True)

    return imgs_p

def train_and_predict_seg():
    print('-'*30)
    print('Loading and preprocessing train data...')
    print('-'*30)
    print('-'*40)
print('Loading and preprocessing train data...')
print('-'*40)
imgs_train, imgs_mask_train = load_train_data_312()

imgs_train, imgs_mask_train = shift_augmentation(
    imgs_train, imgs_mask_train, 0.05, 0.1)

imgs_train = preprocess(imgs_train)
imgs_mask_train = preprocess(imgs_mask_train)

imgs_train = imgs_train.astype('float32')

mean = np.mean(imgs_train)  # mean for data centering
std = np.std(imgs_train)  # std for data normalization

imgs_train -= mean
imgs_train /= std

save_mean_std(mean, std, '3ch_meanstd_d2.npy')

imgs_mask_train = imgs_mask_train.astype('float32')
imgs_mask_train /= 255.  # scale masks to [0, 1]

print('-'*40)
print('Creating and compiling model...')
print('-'*40)
seg_model = get_unet()
seg_model.compile(optimizer=Adam(lr=1e-4), loss=dice_coef_loss, metrics=[dice_coef])
#seg_model.load_weights('weights_seg_3ch.h5')
model_checkpoint = ModelCheckpoint('weights_seg_3ch_d2_312.h5', monitor='val_loss', save_best_only=True)

print('-'*40)
print('Fitting model...')
print('-'*40)
seg_model.fit(imgs_train, imgs_mask_train, batch_size=55, epochs=20, verbose=1, shuffle=True,
          validation_split=0.1,
          callbacks=[model_checkpoint])
print('-'*40)
print('Training Done.')
print('-'*40)

    ### predict
imgs_test, imgs_id_test = load_test_data_312()
imgs_test = preprocess(imgs_test)
#imgs_mask_test_true = np.load('imgs_mask_test.npy')
#imgs_mask_test_true = preprocess(imgs_mask_test_true)

mean, std = load_mean_std('3ch_meanstd_d2.npy')

imgs_test = imgs_test.astype('float32')
imgs_test -= mean
imgs_test /= std

print('-'*30)
print('Loading saved weights...')
print('-'*30)
seg_model = get_unet()
seg_model.load_weights('weights_seg_3ch_d2_312.h5')

print('-'*30)
print('Predicting masks on test data...')
print('-'*30)
imgs_mask_test = seg_model.predict(imgs_test, verbose=1)
np.save('imgs_mask_test_pred_d2_312.npy', imgs_mask_test)

print('-' * 30)
print('Saving predicted masks to files...')
print('-' * 30)
imgs_mask_test_orig = de_crop_resize(imgs_mask_test, Resize = True)
if not os.path.exists(pred_dir):
    os.mkdir(pred_dir)
for image, image_id in zip(imgs_mask_test_orig, imgs_id_test):
    image = ((image[:, :, 0] > 0.5) * 255.).astype(np.uint8)
    imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
print('-' * 30)
print('Saving Done.')
print('-' * 30)

# %%
print('-'*40)
print('Loading and preprocessing train data...')
print('-'*40)
imgs_train, imgs_mask_train = load_train_data_312()

imgs_train, imgs_mask_train = shift_augmentation(
    imgs_train, imgs_mask_train, 0.05, 0.1)

imgs_train = preprocess(imgs_train)
imgs_mask_train = preprocess(imgs_mask_train)

imgs_train = imgs_train.astype('float32')

mean = np.mean(imgs_train)  # mean for data centering
std = np.std(imgs_train)  # std for data normalization

imgs_train -= mean
imgs_train /= std

save_mean_std(mean, std, '3ch_meanstd_d2_312.npy')

imgs_mask_train = imgs_mask_train.astype('float32')
imgs_mask_train /= 255.  # scale masks to [0, 1]
# Out:
# ----------------------------------------
# Loading and preprocessing train data...
# ----------------------------------------
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
print('-'*40)
print('Creating and compiling model...')
print('-'*40)
seg_model = get_unet()
seg_model.compile(optimizer=Adam(lr=1e-4), loss=dice_coef_loss, metrics=[dice_coef])
#seg_model.load_weights('weights_seg_3ch.h5')
model_checkpoint = ModelCheckpoint('weights_seg_3ch_d2_312.h5', monitor='val_loss', save_best_only=True)

print('-'*40)
print('Fitting model...')
print('-'*40)
seg_model.fit(imgs_train, imgs_mask_train, batch_size=55, epochs=20, verbose=1, shuffle=True,
          validation_split=0.1,
          callbacks=[model_checkpoint])
print('-'*40)
print('Training Done.')
print('-'*40)
# Out:
# ----------------------------------------
# Creating and compiling model...
# ----------------------------------------
# ----------------------------------------
# Fitting model...
# ----------------------------------------
# Train on 657 samples, validate on 73 samples
# Epoch 1/20
# 657/657 [==============================] - 697s 1s/step - loss: -0.1167 - dice_coef: 0.1167 - val_loss: -0.1938 - val_dice_coef: 0.1938
# Epoch 2/20
# 657/657 [==============================] - 655s 997ms/step - loss: -0.2816 - dice_coef: 0.2816 - val_loss: -0.1971 - val_dice_coef: 0.1971
# Epoch 3/20
# 657/657 [==============================] - 656s 999ms/step - loss: -0.5620 - dice_coef: 0.5620 - val_loss: -0.6371 - val_dice_coef: 0.6371
# Epoch 4/20
# 657/657 [==============================] - 651s 990ms/step - loss: -0.7987 - dice_coef: 0.7987 - val_loss: -0.8024 - val_dice_coef: 0.8024
# Epoch 5/20
# 657/657 [==============================] - 653s 993ms/step - loss: -0.8752 - dice_coef: 0.8752 - val_loss: -0.8852 - val_dice_coef: 0.8852
# Epoch 6/20
# 657/657 [==============================] - 647s 985ms/step - loss: -0.9035 - dice_coef: 0.9035 - val_loss: -0.9067 - val_dice_coef: 0.9067
# Epoch 7/20
# 657/657 [==============================] - 653s 993ms/step - loss: -0.9131 - dice_coef: 0.9131 - val_loss: -0.9155 - val_dice_coef: 0.9155
# Epoch 8/20
# 657/657 [==============================] - 647s 984ms/step - loss: -0.9209 - dice_coef: 0.9209 - val_loss: -0.9287 - val_dice_coef: 0.9287
# Epoch 9/20
# 657/657 [==============================] - 644s 981ms/step - loss: -0.9235 - dice_coef: 0.9235 - val_loss: -0.9188 - val_dice_coef: 0.9188
# Epoch 10/20
# 657/657 [==============================] - 648s 986ms/step - loss: -0.9278 - dice_coef: 0.9278 - val_loss: -0.9367 - val_dice_coef: 0.9367
# Epoch 11/20
# 657/657 [==============================] - 647s 984ms/step - loss: -0.9302 - dice_coef: 0.9302 - val_loss: -0.9204 - val_dice_coef: 0.9204
# Epoch 12/20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-050c7d29ed7a> in <module>()
#      12 seg_model.fit(imgs_train, imgs_mask_train, batch_size=55, epochs=20, verbose=1, shuffle=True,
#      13           validation_split=0.1,
# ---> 14           callbacks=[model_checkpoint])
#      15 print('-'*40)
#      16 print('Training Done.')
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1710                               initial_epoch=initial_epoch,
#    1711                               steps_per_epoch=steps_per_epoch,
# -> 1712                               validation_steps=validation_steps)
#    1713
#    1714     def evaluate(self, x=None, y=None,
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1233                         ins_batch[i] = ins_batch[i].toarray()
#    1234
# -> 1235                     outs = f(ins_batch)
#    1236                     if not isinstance(outs, list):
#    1237                         outs = [outs]
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2473         session = get_session()
#    2474         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2475                               **self.session_kwargs)
#    2476         return updated[:len(self.outputs)]
#    2477
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
### predict
imgs_test, imgs_id_test = load_test_data_312()
imgs_test = preprocess(imgs_test)
#imgs_mask_test_true = np.load('imgs_mask_test.npy')
#imgs_mask_test_true = preprocess(imgs_mask_test_true)

mean, std = load_mean_std('3ch_meanstd_d2_312.npy')

imgs_test = imgs_test.astype('float32')
imgs_test -= mean
imgs_test /= std

print('-'*30)
print('Loading saved weights...')
print('-'*30)
seg_model = get_unet()
seg_model.load_weights('weights_seg_3ch_d2_312.h5')

print('-'*30)
print('Predicting masks on test data...')
print('-'*30)
imgs_mask_test = seg_model.predict(imgs_test, verbose=1)
np.save('imgs_mask_test_pred_d2_312.npy', imgs_mask_test)

print('-' * 30)
print('Saving predicted masks to files...')
print('-' * 30)
imgs_mask_test_orig = de_crop_resize(imgs_mask_test, Resize = True)
pred_dir = 'preds_d2_312'
if not os.path.exists(pred_dir):
    os.mkdir(pred_dir)
for image, image_id in zip(imgs_mask_test_orig, imgs_id_test):
    image = ((image[:, :, 0] > 0.5) * 255.).astype(np.uint8)
    imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
print('-' * 30)
print('Saving Done.')
print('-' * 30)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# ------------------------------
# Loading saved weights...
# ------------------------------
# ------------------------------
# Predicting masks on test data...
# ------------------------------
# 267/267 [==============================] - 94s 353ms/step
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt11_4ch_031_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt11_4ch_032_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt11_4ch_033_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt11_4ch_058_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt11_4ch_059_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt11_4ch_060_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt11_4ch_061_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt11_4ch_062_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt11_4ch_063_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt11_4ch_064_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt11_4ch_065_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt11_4ch_066_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt11_4ch_067_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt11_4ch_068_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt11_4ch_069_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt11_4ch_084_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt11_4ch_085_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt11_4ch_089_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt11_4ch_090_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_002_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_003_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_004_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_005_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_006_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_007_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_008_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_009_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_010_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_011_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_012_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_013_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_019_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_020_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_021_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_022_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_023_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_024_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_025_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_026_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_027_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_028_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_029_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_030_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_031_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_032_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_033_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_034_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_035_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_036_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_037_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_038_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_039_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_040_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_041_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_042_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_043_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_044_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_045_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_046_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_047_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_048_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_049_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_050_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_051_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_052_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_053_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_054_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_055_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_056_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_057_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_058_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_059_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_060_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_061_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_062_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_063_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_064_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_065_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_066_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_067_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_068_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_069_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_070_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_071_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_072_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_073_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_074_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_075_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt12_4ch_076_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_002_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_003_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_004_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_005_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_006_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_007_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_008_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_009_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_010_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_011_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_012_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_013_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_014_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_015_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_016_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_017_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_018_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_019_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_020_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_021_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_022_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_023_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_024_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_025_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_026_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_027_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_028_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_029_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# ------------------------------
# Saving Done.
# ------------------------------
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_082_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_083_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_084_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_085_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_086_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_087_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_088_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_089_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/io/_io.py:132: UserWarning: preds_d2_312/pt13_4ch_090_pred.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
